# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#!pip install seaborn
import seaborn

# %%
data=pd.read_csv("/Users/srikarprayaga/Desktop/UC-x-Imagine-Datathon/Data_Extract_From_World_Development_Indicators/data_point.csv")

# %%
data
# Out:
#                                         Country Name Country Code  \
# 0                                       South Africa          ZAF
# 1                                       South Africa          ZAF
# 2                                       South Africa          ZAF
# 3                                       South Africa          ZAF
# 4                                       South Africa          ZAF
# 5                                       South Africa          ZAF
# 6                                       South Africa          ZAF
# 7                                       South Africa          ZAF
# 8                                       South Africa          ZAF
# 9                                       South Africa          ZAF
# 10                                      South Africa          ZAF
# 11                                      South Africa          ZAF
# 12                                      South Africa          ZAF
# ...

# %%
#total energy produced in South Africa from 1985 to 2018 in terms of GigsWatt Hours
fred=pd.read_csv("/Users/srikarprayaga/Desktop/UC-x-Imagine-Datathon/fred.csv")
plt.plot(list(fred.loc[:,"PRENEL01ZAQ656N"]))

# %%
# power cuts based on 4 stages with stage 0 being no loadshedding to 4 being high shedding
eskom=pd.read_csv("/Users/srikarprayaga/Desktop/UC-x-Imagine-Datathon/eskom.csv")
unique(eskom.loc[:,"stage"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-5bd1ded707eb> in <module>
#       1 # power cuts based on 4 stages with stage 0 being no loadshedding to 4 being high shedding
#       2 eskom=pd.read_csv("/Users/srikarprayaga/Desktop/UC-x-Imagine-Datathon/eskom.csv")
# ----> 3 unique(eskom.loc[:,"stage"])
#
# NameError: name 'unique' is not defined
